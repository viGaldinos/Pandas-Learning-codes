# %%
import pandas as pd
import numpy as np

# %%
datas = pd.date_range('20180101', periods = 600, freq="D")

df = pd.DataFrame(np.random.randn(600,5), index = datas, columns = list("ABCDE")) 
df.head()
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.422345  0.374000  1.089644 -0.419012  0.251260
# 2018-01-02 -1.224913 -0.118618 -0.058535 -0.242350  0.120231
# 2018-01-03 -0.420460  0.601386  0.115432  0.597997 -0.118062
# 2018-01-04 -0.509503  1.377034 -1.434764 -1.890307 -1.775832
# 2018-01-05 -0.420588  0.784096  0.728002 -0.362817 -0.419636

# %%
df['D']
# Out:
# 2018-01-01   -0.419012
# 2018-01-02   -0.242350
# 2018-01-03    0.597997
# 2018-01-04   -1.890307
# 2018-01-05   -0.362817
#                 ...
# 2019-08-19   -2.413805
# 2019-08-20    0.504138
# 2019-08-21   -0.280478
# 2019-08-22    1.236494
# 2019-08-23    0.637002
# Freq: D, Name: D, Length: 600, dtype: float64

# %%
df[1:5]
# Out:
#                    A         B         C         D         E
# 2018-01-02 -1.224913 -0.118618 -0.058535 -0.242350  0.120231
# 2018-01-03 -0.420460  0.601386  0.115432  0.597997 -0.118062
# 2018-01-04 -0.509503  1.377034 -1.434764 -1.890307 -1.775832
# 2018-01-05 -0.420588  0.784096  0.728002 -0.362817 -0.419636

# %%
df.loc[:,['B', 'C', 'D']].head()
# Out:
#                    B         C         D
# 2018-01-01  0.374000  1.089644 -0.419012
# 2018-01-02 -0.118618 -0.058535 -0.242350
# 2018-01-03  0.601386  0.115432  0.597997
# 2018-01-04  1.377034 -1.434764 -1.890307
# 2018-01-05  0.784096  0.728002 -0.362817

# %%
df.loc['20180203':'20180930', ['A', 'E']].tail()
# Out:
#                    A         E
# 2018-09-26 -0.169602 -0.244110
# 2018-09-27 -1.410345 -0.440413
# 2018-09-28  2.127429 -0.187263
# 2018-09-29  0.811682 -0.702459
# 2018-09-30  0.016854  0.481545

# %%
df.iloc[1]
# Out:
# A   -1.224913
# B   -0.118618
# C   -0.058535
# D   -0.242350
# E    0.120231
# Name: 2018-01-02 00:00:00, dtype: float64

# %%
df.iloc[0:4, :3]
# Out:
#                    A         B         C
# 2018-01-01  1.422345  0.374000  1.089644
# 2018-01-02 -1.224913 -0.118618 -0.058535
# 2018-01-03 -0.420460  0.601386  0.115432
# 2018-01-04 -0.509503  1.377034 -1.434764

# %%
df.iloc[[1,5,6],[0,3]]
# Out:
#                    A         D
# 2018-01-02 -1.224913 -0.242350
# 2018-01-06  0.170150  0.223616
# 2018-01-07  2.123523  0.249466

# %%
df.iloc[1:3,:]
# Out:
#                    A         B         C         D         E
# 2018-01-02 -1.224913 -0.118618 -0.058535 -0.242350  0.120231
# 2018-01-03 -0.420460  0.601386  0.115432  0.597997 -0.118062

# %%
df.A
# Out:
# 2018-01-01    1.422345
# 2018-01-02   -1.224913
# 2018-01-03   -0.420460
# 2018-01-04   -0.509503
# 2018-01-05   -0.420588
#                 ...
# 2019-08-19   -2.918437
# 2019-08-20   -1.407201
# 2019-08-21    1.426353
# 2019-08-22   -0.855880
# 2019-08-23   -0.112846
# Freq: D, Name: A, Length: 600, dtype: float64

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.422345  0.374000  1.089644 -0.419012  0.251260
# 2018-01-06  0.170150  0.244189 -1.932403  0.223616  0.369933
# 2018-01-07  2.123523 -2.050186  0.332104  0.249466  0.310699
# 2018-01-09  0.816950 -0.013921  1.943211 -1.233598  0.005320
# 2018-01-10  1.732650  0.610849  0.138076 -0.573936 -1.162177
# ...              ...       ...       ...       ...       ...
# 2019-08-14  0.489552  0.987241  0.283590 -0.513952  1.122613
# 2019-08-16  1.501816 -0.410966 -0.014370 -0.773399  1.250932
# 2019-08-17  1.262063  0.894529  0.756171  0.273417  0.588669
# 2019-08-18  0.336428 -0.463117 -1.649745 -1.032496 -0.541643
# 2019-08-21  1.426353 -1.224487  0.656636 -0.280478 -0.694849
#
# [308 rows x 5 columns]

# %%
df.A[df.A > 0]
# Out:
# 2018-01-01    1.422345
# 2018-01-06    0.170150
# 2018-01-07    2.123523
# 2018-01-09    0.816950
# 2018-01-10    1.732650
#                 ...
# 2019-08-14    0.489552
# 2019-08-16    1.501816
# 2019-08-17    1.262063
# 2019-08-18    0.336428
# 2019-08-21    1.426353
# Name: A, Length: 308, dtype: float64

# %%
df[df > 0]
# Out:
#                    A         B         C         D         E
# 2018-01-01  1.422345  0.374000  1.089644       NaN  0.251260
# 2018-01-02       NaN       NaN       NaN       NaN  0.120231
# 2018-01-03       NaN  0.601386  0.115432  0.597997       NaN
# 2018-01-04       NaN  1.377034       NaN       NaN       NaN
# 2018-01-05       NaN  0.784096  0.728002       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2019-08-19       NaN       NaN  0.001421       NaN       NaN
# 2019-08-20       NaN       NaN  0.543247  0.504138  0.683634
# 2019-08-21  1.426353       NaN  0.656636       NaN       NaN
# 2019-08-22       NaN  0.843834       NaN  1.236494  0.209354
# 2019-08-23       NaN       NaN  0.978290  0.637002  0.339631
#
# [600 rows x 5 columns]
