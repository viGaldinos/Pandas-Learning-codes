# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([7 ,3 ,2 ,np.nan ,6 ,9])

# %%
series
# Out:
# 0    7.0
# 1    3.0
# 2    2.0
# 3    NaN
# 4    6.0
# 5    9.0
# dtype: float64

# %%
type(series)
# Out:
# pandas.core.series.Series

# %%
data = pd.date_range('20180101', periods = 6, freq = 'M')

# %%
data
# Out:
# DatetimeIndex(['2018-01-31', '2018-02-28', '2018-03-31', '2018-04-30',
#                '2018-05-31', '2018-06-30'],
#               dtype='datetime64[ns]', freq='M')

# %%
type(data)
# Out:
# pandas.core.indexes.datetimes.DatetimeIndex

# %%
df = pd.DataFrame(np.random.randn(6,4), index = data, columns = list('ABCD'))

# %%
np.random.randn(6,4)
# Out:
# array([[-0.72253124, -0.40450033, -0.77509175, -0.85464564],
#        [-0.83766906, -0.42144321,  0.97721617,  0.06734589],
#        [ 0.94418562, -0.3759646 ,  0.30872734, -0.66315021],
#        [ 0.33733931,  0.20570218, -0.49274665,  0.11302401],
#        [-0.0557202 ,  1.13760566,  0.87397103, -0.3997123 ],
#        [-0.68767448,  0.87847773, -0.4979266 ,  0.08004392]])

# %%
df
# Out:
#                    A         B         C         D
# 2018-01-31 -0.638586 -2.267089  1.258486  1.640727
# 2018-02-28  0.697763 -0.212111 -0.339573 -0.740036
# 2018-03-31  0.179370  0.625082 -1.443982 -0.229995
# 2018-04-30  0.616495 -1.142264 -1.507967  0.940392
# 2018-05-31 -1.098833  0.089097 -1.009515  0.329479
# 2018-06-30  0.655135 -1.511993 -0.508776 -0.297195

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df2 = pd.DataFrame({"A": 7,
                    "B": pd.Timestamp(20190101),
                    "C": pd.Series(1, index = list(range(4)), dtype = 'float32')
                    "D": np.array([3])})
# Out:
#   File "<ipython-input-3-4e4f09d52333>", line 4
#     "D": np.array([3])})
#     ^
# SyntaxError: invalid syntax
