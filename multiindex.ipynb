# %%
import pandas as pd

# %%
arrays = [[1, 2, 3, 4] , ['blue', 'red', 'blue', 'red']]

# %%
pd.MultiIndex.from_arrays(arrays, names = ('number', 'color'))
# Out:
# MultiIndex([(1, 'blue'),
#             (2,  'red'),
#             (3, 'blue'),
#             (4,  'red')],
#            names=['number', 'color'])
